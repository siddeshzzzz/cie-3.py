# %% [markdown]
# <a href="https://colab.research.google.com/github/siddeshzzzz/cie-3.py/blob/main/CIE_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('/content/auto-mpg.csv')
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 393  27.0          4         140.0         86    2790          15.6    82
# 394  44.0          4          97.0         52    2130          24.6    82
# 395  32.0          4         135.0         84    2295          11.6    82
# 396  28.0          4         120.0         79    2625          18.6    82
# 397  31.0          4         119.0         82    2720          19.4    82
#
#      origin                       name
# 0         1  chevrolet chevelle malibu
# ...

# %%
df.drop('weight',axis=1,inplace=True)
df
# Out:
#       mpg  cylinders  displacement horsepower  acceleration  year  origin  \
# 0    18.0          8         307.0        130          12.0    70       1
# 1    15.0          8         350.0        165          11.5    70       1
# 2    18.0          8         318.0        150          11.0    70       1
# 3    16.0          8         304.0        150          12.0    70       1
# 4    17.0          8         302.0        140          10.5    70       1
# ..    ...        ...           ...        ...           ...   ...     ...
# 393  27.0          4         140.0         86          15.6    82       1
# 394  44.0          4          97.0         52          24.6    82       2
# 395  32.0          4         135.0         84          11.6    82       1
# 396  28.0          4         120.0         79          18.6    82       1
# 397  31.0          4         119.0         82          19.4    82       1
#
#                           name
# 0    chevrolet chevelle malibu
# ...

# %%
x=df['year']
display(x)
# Out:
# 0      70
# 1      70
# 2      70
# 3      70
# 4      70
#        ..
# 393    82
# 394    82
# 395    82
# 396    82
# 397    82
# Name: year, Length: 398, dtype: int64

# %%
y=df.origin
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 393    1
# 394    2
# 395    1
# 396    1
# 397    1
# Name: origin, Length: 398, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df[['year']],df[['origin']])

# %%
x_train
# Out:
#      year
# 306    79
# 68     72
# 130    74
# 166    75
# 261    78
# ..    ...
# 277    78
# 350    81
# 389    82
# 393    82
# 119    73
#
# [298 rows x 1 columns]

# %%
y_train
# Out:
#      origin
# 306       1
# 68        1
# 130       1
# 166       1
# 261       1
# ..      ...
# 277       2
# 350       1
# 389       1
# 393       1
# 119       2
#
# [298 rows x 1 columns]

# %%
y_test
# Out:
#      origin
# 372       1
# 26        1
# 338       1
# 183       2
# 20        2
# ..      ...
# 102       2
# 259       1
# 10        1
# 48        1
# 190       1
#
# [100 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
x_pred=lr.predict(x_train)
print("x_pred",x_pred)
print("y_pred",y_pred)
# Out:
# x_pred [[1.60749763]
#  [1.40653427]
#  [1.46395237]
#  [1.49266142]
#  [1.57878858]
#  [1.63620668]
#  [1.52137047]
#  [1.49266142]
#  [1.66491573]
#  [1.66491573]
#  [1.34911616]
#  [1.66491573]
#  [1.60749763]
#  [1.37782521]
#  [1.69362478]
#  [1.43524332]
#  [1.34911616]
#  [1.49266142]
#  [1.43524332]
#  [1.37782521]
#  [1.46395237]
#  [1.49266142]
#  [1.43524332]
#  [1.69362478]
#  [1.60749763]
#  [1.57878858]
#  [1.34911616]
#  [1.40653427]
#  [1.63620668]
#  [1.52137047]
#  [1.63620668]
#  [1.46395237]
#  [1.69362478]
#  [1.57878858]
#  [1.66491573]
#  [1.55007952]
#  [1.57878858]
#  [1.55007952]
#  [1.43524332]
#  [1.52137047]
#  [1.46395237]
#  [1.55007952]
#  [1.69362478]
#  [1.37782521]
#  [1.66491573]
#  [1.63620668]
#  [1.63620668]
#  [1.37782521]
#  [1.49266142]
#  [1.63620668]
#  [1.55007952]
#  [1.43524332]
#  [1.63620668]
#  [1.52137047]
#  [1.40653427]
#  [1.46395237]
#  [1.34911616]
#  [1.60749763]
#  [1.40653427]
#  [1.40653427]
#  [1.55007952]
#  [1.63620668]
# ...

# %%
y_test
# Out:
#      origin
# 372       1
# 26        1
# 338       1
# 183       2
# 20        2
# ..      ...
# 102       2
# 259       1
# 10        1
# 48        1
# 190       1
#
# [100 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
mse = mean_squared_error(y_test,y_pred)
mae = mean_absolute_error(y_test,y_pred)
r2 = r2_score(y_test , y_pred)
rmse = np.sqrt(mse)
rmse
# Out:
# np.float64(0.8574802518990988)
